# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# TODO
row_max = ds['price'].idxmax()
print ('La casa con dirección en ' + ds.loc[row_max]['address'] + ' es la más cara y su precio es de ' + str(ds.loc[row_max]['price']) + '€')
# Out:
# La casa con dirección en El Escorial es la más cara y su precio es de 8500000€

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO
row_min = ds['price'].idxmin()
print ('La casa con dirección en ' + ds.loc[row_min]['address'] + ' es la más barata y su precio es de ' + str(ds.loc[row_min]['price']) + '€')
# Out:
# La casa con dirección en Parla es la más barata y su precio es de 0€

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# TODO
row_surface_max = ds['surface'].idxmax()
print ('La casa más grande está ubicada en ' + ds.loc[row_surface_max]['address'] + ' y su superficie es de ' + str(ds.loc[row_surface_max]['surface']))
row_surface_min = ds['surface'].idxmin()
print ('La casa más pequeña está ubicada en ' + ds.loc[row_surface_min]['address'] + ' y su superficie es de ' + str(ds.loc[row_surface_min]['surface']))
# Out:
# La casa más grande está ubicada en Sevilla la Nueva y su superficie es de 249000.0
# La casa más pequeña está ubicada en Calle Amparo,  Madrid Capital y su superficie es de 15.0

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO
populations = ds['level5'].unique()
print(', '.join(populations))
# Out:
# Arganda del Rey, Fuenlabrada, Boadilla del Monte, Las Rozas de Madrid,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes, Rivas-vaciamadrid, Alpedrete, Móstoles, San Fernando de Henares, Coslada, Becerril de la Sierra, Alcalá de Henares, Chinchón, Parla, Alcorcón, El Escorial, Leganés, Pedrezuela, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Torrelodones, Moralzarzal, Mejorada del Campo, Aranjuez, Corpa, Getafe, Velilla de San Antonio, Sevilla la Nueva, San Martín de la Vega, Villalbilla, Collado Villalba, Alcobendas, El Molar (Madrid), Moraleja de Enmedio, Algete, Campo Real, Torrejón de la Calzada, Colmenar Viejo, Valdemorillo, Fuente El Saz de Jarama, Tres Cantos, Arroyomolinos (Madrid), Griñón, Paracuellos de Jarama, Guadarrama, Titulcia, Galapagar, Collado Mediano, Los Molinos, San Lorenzo de El Escorial, Loeches, San Martín de Valdeiglesias, Navas del Rey, Bus
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO

print(ds.isna().any())
print(ds.isna().any(axis=1))
# Out:
# Unnamed: 0          False
# id_realEstates      False
# isNew               False
# realEstate_name      True
# phone_realEstate     True
# url_inmueble        False
# rooms                True
# bathrooms            True
# surface              True
# price               False
# date                False
# description          True
# address             False
# country             False
# level1              False
# level2              False
# level3              False
# level4               True
# level5              False
# level6               True
# level7               True
# level8               True
# upperLevel          False
# countryId           False
# level1Id            False
# level2Id            False
# level3Id            False
# level4Id            False
# level5Id            False
# level6Id            False
# level7Id            False
# level8Id            False
# accuracy            False
# latitude            False
# longitude           False
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# TODO
print('Las dimensiones del DataFrame original es ' + str(ds.shape))
ds.dropna(axis=1, inplace=True, how='all')
ds.dropna(axis=0, inplace=True, how='all')
print('Las dimensiones del DataFrame sin nulos es' + str(ds.shape))
# Out:
# Las dimensiones del DataFrame original es (15335, 37)
# Las dimensiones del DataFrame sin nulos es(15335, 35)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# TODO
ds_arroyomolinos = ds[ds['level5']=='Arroyomolinos (Madrid)']
print ('La media es ' + str(ds_arroyomolinos['price'].mean()))
# Out:
# La media es 294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
# TODO: Code
import matplotlib.pyplot as plt

ds_arroyomolinos['price'].hist()
# Out:
# <Axes: >

# %% [markdown]
# **TODO: Markdown**.
# Se puede ver que la mayoría de los edificios se situan alrededor de los 300.000€. Encontrandose la mayoría entre los 200.000€ y los 400.000€. Se puede ver una cola apartir de los 400.000€ y algún valor anómalo cerca del 0€.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# TODO
ds_valdemorillo = ds[ds['level5']=='Valdemorillo']
ds_galapagar = ds[ds['level5']=='Galapagar']


print('El precio promedio de Valdemorillo es de ' + str(ds_galapagar['price'].mean()))
print('El precio promedio de Galapagar es de ' + str(ds_valdemorillo['price'].mean()))
print('El precio no coincide, aunque parecidos en los dos lugares.')
# Out:
# El precio promedio de Valdemorillo es de 360063.20238095237
# El precio promedio de Galapagar es de 363860.2931034483
# El precio no coincide, aunque parecidos en los dos lugares.

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# TODO
ds['pps'] =  ds['price'] / ds['surface']
ds_valdemorillo = ds[ds['level5']=='Valdemorillo']
ds_galapagar = ds[ds['level5']=='Galapagar']

print('El precio por m2 promedio de Valdemorillo es de ' + str(ds_galapagar['pps'].mean()))
print('El precio por m2 promedio de Galapagar es de ' + str(ds_valdemorillo['pps'].mean()))
print('Aunque los precios eran parecidos, el precio por m2 se encuentra superior en Valdemorillo.')
# Out:
# El precio por m2 promedio de Valdemorillo es de 1606.3240303094024
# El precio por m2 promedio de Galapagar es de 1317.9502109024986
# Aunque los precios eran parecidos, el precio por m2 se encuentra superior en Valdemorillo.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
# TODO: Código
plt.scatter(ds['surface'], ds['price'])
plt.xlabel('surface')
plt.ylabel('price')
plt.show()

ds_filtered = ds[ds['surface']<3000]
plt.scatter(ds_filtered['surface'], ds_filtered['price'])
plt.xlabel('surface')
plt.ylabel('price')
plt.show()

# %% [markdown]
# Parece que el tamaño mínimo aumente el precio miínimo de la casa, pero no tanto con el tamaño máximo.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# TODO
real_estate_unique = ds['realEstate_name'].unique()
print('El número de agencias son ' + str(real_estate_unique.size))
# Out:
# El número de agencias son 1822

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# TODO
# ds['price'].idxmax()
count_level5 = ds.groupby('level5').size().reset_index(name='count')
max_population_id = count_level5['count'].idxmax()
print('La población con mas casas es ' + count_level5.loc[max_population_id]['level5'] + 'con el número de ' + str(count_level5.loc[max_population_id]['count']) + ' casas')
# Out:
# La población con mas casas es  Madrid Capitalcon el número de 6643 casas

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# TODO
ds_madrid_sur = ds[ds['level5'].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# TODO: Code
import seaborn as sns

ds_madrid_sur_mean = ds_madrid_sur.groupby('level5')['price'].mean().reset_index()

plt.figure()
sns.barplot(x='level5', y='price', data=ds_madrid_sur_mean)
plt.xlabel('Población')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# Se purde ver que el precio es bastante superior en Getafe que en la población de Fuenlabrada con unadistancia superior a los 50.000€.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# TODO
# price, rooms, surface, bathrooms
ds_madrid_sur_agg = ds_madrid_sur.groupby('level5').agg(
    price_mean=('price', 'mean'),
    price_var=('price', 'var'),
    rooms_mean=('rooms', 'mean'),
    rooms_var=('rooms', 'var'),
    surface_mean=('surface', 'mean'),
    surface_var=('surface', 'var'),
    bathrooms_mean=('bathrooms', 'mean'),
    bathrooms_var=('bathrooms', 'var')
)
print(ds_madrid_sur_agg)
# Out:
#                 price_mean     price_var  rooms_mean  rooms_var  surface_mean  \
# level5
# Alcorcón     230071.052632  1.594783e+10    2.914894   0.933895    105.913295
# Fuenlabrada  177198.021459  4.701021e+09    3.025974   0.355844    103.624365
# Getafe       265040.500000  2.098267e+10    3.151724   0.772748    126.896266
# Leganés      208682.010309  1.191394e+10    2.906736   0.824590    105.852273
#
#              surface_var  bathrooms_mean  bathrooms_var
# level5
# Alcorcón     4244.323834        1.623656       0.592735
# Fuenlabrada  2264.643893        1.445415       0.353367
# Getafe       5828.110028        1.865052       0.658809
# Leganés      3987.475195        1.518135       0.553055

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# TODO
ds_madrid_sur_price_max = ds_madrid_sur.groupby('level5').agg(
    price_max=('price', 'max')
)
print(ds_madrid_sur_price_max)
# Out:
#              price_max
# level5
# Alcorcón        950000
# Fuenlabrada     490000
# Getafe         1050000
# Leganés         650000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# TODO
ds_madrid_sur['price_std'] = ds_madrid_sur.groupby('level5')['price'].transform(lambda x: (x - x.mean()) / x.std())
for city in ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]:
    ds_madrid_sur[ds_madrid_sur['level5'] == city]['price'].plot(kind='hist')
    plt.title(f'Histogram of {city}')
    plt.xlabel('Price')
    plt.ylabel('Frequency')
    plt.show()
# Out:
# C:\Users\darkc\AppData\Local\Temp\ipykernel_4284\3036725124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_madrid_sur['price_std'] = ds_madrid_sur.groupby('level5')['price'].transform(lambda x: (x - x.mean()) / x.std())

# %% [markdown]
# Se ve que la frequencia mas alta Getafe esta entorno a los 400.000€ sin embargo en las otras esta entorno a los 150.000€-200.000€ dando a ver que las casas son mas caras en Getafe que en el resto de poblaciones

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# TODO
ds_madrid_sur_pps = ds_madrid_sur.groupby('level5').agg(
    pps_mean=('pps', 'mean'),
    pps_var=('pps', 'var'),
    pps_max=('pps', 'max'),
    pps_min=('pps', 'min')
)
print(ds_madrid_sur_pps)
print('A pesar de que el precio medio es superior en Alcorcón,')
print('podemos ver que la varianza es vastante mayor en Getafe donde encontramos la casa con el pps mayor')
# Out:
#                 pps_mean        pps_var      pps_max      pps_min
# level5
# Alcorcón     2239.302480  291547.651085  3698.159509   604.761905
# Fuenlabrada  1796.729220  163561.898348  3917.525773  1034.883721
# Getafe       2066.314949  550375.106197  3827.160494     0.000000
# Leganés      2047.503268  225190.658496  3513.513514  1000.000000
# A pesar de que el precio medio es superior en Alcorcón,
# podemos ver que la varianza es vastante mayor en Getafe donde encontramos la casa con el pps mayor

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# TODO
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(12, 6))
for ax, value in zip(axes, ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]):
    subset = ds_madrid_sur[ds_madrid_sur['level5'] == value]
    ax.scatter(subset['price'], subset['surface'])
    ax.set_title(value)
    ax.set_xlabel('price')
    ax.set_ylabel('surface')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20)
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:
from ipyleaflet import Marker, MarkerCluster
coordinates = ds_madrid_sur[['latitude', 'longitude']].to_dict(orient='records')

marker_list = []
for coordinate in coordinates:
    position = (float(coordinate['latitude'].replace(',', '.')), float(coordinate['longitude'].replace(',', '.')))
    marker = Marker(location=position, draggable=False)
    marker_list.append(marker)
marker_cluster = MarkerCluster(markers=marker_list)
map.add(marker_cluster)
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…
